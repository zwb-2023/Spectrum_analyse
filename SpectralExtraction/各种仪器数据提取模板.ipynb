# %% [markdown]
# ### Siware 数据提取

# %%
import pandas as pd  # 导入pandas库，用于数据处理和分析
import numpy as np
import glob

list_path = glob.glob(rf'I:\experiment_data\莲蓉混合\纯蓉\*.csv')
df = pd.read_csv(list_path[0])  # 使用read_csv函数读取CSV文件
wavelenth = df.columns.tolist()[4:-1]
name = df.iloc[:,0].tolist()
df1 = df.iloc[:,4:-1]
df1.index = name
mean = np.mean(np.array(df1) , axis=0)

# 替换wavelenth里面所有字符串为float
for i in range(len(wavelenth)):
  wavelenth[i] = float(wavelenth[i])
wavelengths = 10000000/np.array(wavelenth)

# %%
def get_mean(path):
  df = pd.read_csv(path)  # 使用read_csv函数读取CSV文件，并且重复数据取平均
  name = df.iloc[:,0].tolist()
  df1 = df.iloc[:,4:-1]
  df1.index = name
  mean = np.mean(np.array(df1) , axis=0)
  labels = name[0]
  return mean , labels

# %%
def get_data(path):
  df = pd.read_csv(path)  # 使用read_csv函数读取CSV文件，并且重复数据取平均
  name = path.split('\\')[-1][:-4]
  df1 = df.iloc[:,4:-1]
  data = np.array(df1)
  labels = name
  return data , labels

# %%
datas = [] 
labels = []
for path in list_path :
  data , label = get_data(path)
  datas.append(data[0])
  labels.append(label)

datas = np.array(datas)
labels = np.array(labels)

# %%
df = pd.DataFrame(datas , index = labels , columns = wavelengths)
df
# Out:
#           2550.169685  2540.625116  2531.151727  2521.748723  2512.415324  \
# 纯白莲蓉_1       1.745430     1.692365     1.649040     1.613772     1.584676
# 纯白莲蓉_2       1.604357     1.561687     1.523034     1.486467     1.451839
# 纯白莲蓉_3       1.615589     1.566979     1.525130     1.488257     1.455313
# 纯白莲蓉_4       1.704767     1.655301     1.615502     1.582559     1.553801
# 纯白莲蓉_6       1.664939     1.614961     1.569696     1.528381     1.491589
# 纯白豆蓉_1_0     1.744311     1.699745     1.664073     1.634395     1.608124
# 纯白豆蓉_2_0     2.186667     2.136601     2.097519     2.066715     2.040982
# 纯白豆蓉_3_0     1.873017     1.826879     1.789828     1.759775     1.734665
# 纯白豆蓉_4_0     2.162968     2.116544     2.079675     2.048006     2.018331
# 纯白豆蓉_5_0     2.225631     2.181190     2.147928     2.121747     2.099000
# 纯白豆蓉_6_0     1.952408     1.914446     1.888612     1.867486     1.844919
# 纯白豆蓉_7_0     2.075473     2.026250     1.991269     1.965975     1.944916
# 纯白豆蓉_8_0     3.260008     3.211288     3.174029     3.142544     3.113248
# 纯红豆沙_1_0     1.730465     1.684066     1.650050     1.623182     1.599130
# 纯红豆沙_2_0     1.544818     1.500175     1.462211     1.429433     1.400554
# 纯红豆沙_3_0     1.831755     1.790511     1.758967     1.731504     1.704475
# 纯红豆沙_4_0     1.770363     1.724109     1.686554     1.654083     1.624365
# 纯红豆沙_5_0     1.589951     1.542043     1.506281     1.478855     1.455902
# 纯红豆沙_6_0     1.664959     1.619176     1.584899     1.557834     1.533834
# 纯红豆沙_7_0     2.068616     2.022410     1.988742     1.961167     1.934744
# 纯红豆沙_8_0     2.116306     2.066702     2.029676     1.999023     1.970484
# 纯豌豆蓉_1_0     1.720185     1.670287     1.630870     1.601124     1.578386
# 纯豌豆蓉_2_0     1.846543     1.799573     1.760647     1.727993     1.699349
# 纯豌豆蓉_3_0     1.788022     1.740982     1.701511     1.669369     1.642752
# 纯豌豆蓉_4_0     1.765310     1.723067     1.690564     1.664260     1.640743
# 纯豌豆蓉_5_0     1.696491     1.655299     1.623959     1.597889     1.572300
# 纯豌豆蓉_6_0     2.976348     2.921407     2.875380     2.837313     2.805628
# 纯豌豆蓉_7_0     2.523710     2.473392     2.433372     2.401867     2.376011
# 纯豌豆蓉_8_0     2.528392     2.482001     2.447386     2.419536     2.393488
#
#           2503.150758  2493.954268  2484.825106  2475.762535  2466.765829  \
# 纯白莲蓉_1       1.560002     1.537819     1.516937     1.496853     1.477793
# 纯白莲蓉_2       1.420391     1.393304     1.371028     1.353151     1.338654
# 纯白莲蓉_3       1.426250     1.401267     1.380617     1.364080     1.350760
# 纯白莲蓉_4       1.527247     1.501791     1.477304     1.454172     1.432992
# 纯白莲蓉_6       1.460908     1.436876     1.418939     1.405417     1.393986
# 纯白豆蓉_1_0     1.583770     1.561185     1.541242     1.525018     1.513098
# 纯白豆蓉_2_0     2.017794     1.996180     1.977000     1.961923     1.952299
# 纯白豆蓉_3_0     1.712893     1.693209     1.675230     1.659151     1.645487
# 纯白豆蓉_4_0     1.989744     1.963840     1.943226     1.929985     1.924512
# 纯白豆蓉_5_0     2.077269     2.055876     2.035545     2.017604     2.003359
# 纯白豆蓉_6_0     1.817785     1.787949     1.759630     1.737290     1.723727
# 纯白豆蓉_7_0     1.923539     1.900463     1.877452     1.857900     1.845019
# 纯白豆蓉_8_0     3.085191     3.059503     3.037827     3.021283     3.010015
# 纯红豆沙_1_0     1.575400     1.551750     1.529171     1.508824     1.491404
# 纯红豆沙_2_0     1.374436     1.349926     1.326457     1.304074     1.283365
# 纯红豆沙_3_0     1.677122     1.651321     1.629238     1.611895     1.598601
# 纯红豆沙_4_0     1.596886     1.572389     1.551867     1.535693     1.523253
# 纯红豆沙_5_0     1.434258     1.412225     1.389763     1.367813     1.347692
# 纯红豆沙_6_0     1.509901     1.485276     1.460990     1.438817     1.420319
# 纯红豆沙_7_0     1.907493     1.880940     1.857853     1.840386     1.828901
# 纯红豆沙_8_0     1.942731     1.917022     1.895162     1.878025     1.864948
# 纯豌豆蓉_1_0     1.559419     1.541819     1.525660     1.512842     1.505921
# 纯豌豆蓉_2_0     1.673250     1.649912     1.631241     1.619641     1.616618
# 纯豌豆蓉_3_0     1.619063     1.596236     1.574384     1.555586     1.542929
# 纯豌豆蓉_4_0     1.617894     1.595764     1.575993     1.560633     1.551015
# 纯豌豆蓉_5_0     1.543794     1.512777     1.482410     1.457074     1.440488
# 纯豌豆蓉_6_0     2.779059     2.756852     2.739651     2.728768     2.725227
# 纯豌豆蓉_7_0     2.352772     2.330030     2.307661     2.287118     2.270678
# 纯豌豆蓉_8_0     2.366188     2.338295     2.312891     2.293663     2.283097
#
#           ...  1322.753906  1320.181383  1317.618847  1315.066239  \
# 纯白莲蓉_1    ...     2.206431     2.209414     2.227491     2.267346
# 纯白莲蓉_2    ...     2.279474     2.333536     2.402924     2.475445
# 纯白莲蓉_3    ...     1.988427     2.001001     2.038696     2.097581
# 纯白莲蓉_4    ...     2.008279     2.082181     2.168693     2.243499
# 纯白莲蓉_6    ...     2.553718     2.587755     2.632104     2.681996
# 纯白豆蓉_1_0  ...     4.666943     4.790760     4.909235     5.017315
# 纯白豆蓉_2_0  ...     5.165733     5.262864     5.338717     5.405571
# 纯白豆蓉_3_0  ...     4.937478     5.036614     5.116886     5.186079
# 纯白豆蓉_4_0  ...     5.961730     6.088436     6.210794     6.323783
# 纯白豆蓉_5_0  ...     5.915617     6.050412     6.175090     6.284877
# 纯白豆蓉_6_0  ...     5.481608     5.553541     5.630823     5.730152
# 纯白豆蓉_7_0  ...     5.348791     5.444667     5.537093     5.632365
# 纯白豆蓉_8_0  ...     6.910992     7.021703     7.115285     7.208771
# 纯红豆沙_1_0  ...     2.574209     2.633023     2.678941     2.707675
# 纯红豆沙_2_0  ...     1.939358     1.952939     1.973743     2.006125
# 纯红豆沙_3_0  ...     2.408369     2.442661     2.512001     2.598680
# 纯红豆沙_4_0  ...     2.398242     2.395174     2.429347     2.495551
# 纯红豆沙_5_0  ...     2.559605     2.590251     2.614097     2.635181
# 纯红豆沙_6_0  ...     2.391637     2.442295     2.501650     2.562303
# 纯红豆沙_7_0  ...     2.966125     2.995507     3.022435     3.049642
# 纯红豆沙_8_0  ...     2.919045     2.953257     2.999337     3.055418
# 纯豌豆蓉_1_0  ...     8.879105     9.036128     9.185144     9.332371
# 纯豌豆蓉_2_0  ...     8.304534     8.516302     8.711735     8.877742
# 纯豌豆蓉_3_0  ...     8.245811     8.434246     8.600755     8.747292
# 纯豌豆蓉_4_0  ...     7.191179     7.400176     7.588076     7.754595
# 纯豌豆蓉_5_0  ...     6.010203     6.138646     6.266164     6.396389
# 纯豌豆蓉_6_0  ...     9.158669     9.299508     9.427084     9.553715
# 纯豌豆蓉_7_0  ...     7.702211     7.806282     7.886042     7.976876
# 纯豌豆蓉_8_0  ...     8.480683     8.635866     8.768699     8.887069
#
#           1312.523503  1309.990581  1307.467416  1304.953952  1302.450133  \
# 纯白莲蓉_1       2.326685     2.396089     2.463920     2.521731     2.567568
# 纯白莲蓉_2       2.540072     2.589539     2.622836     2.644392     2.660664
# 纯白莲蓉_3       2.166268     2.229802     2.275893     2.299364     2.303632
# 纯白莲蓉_4       2.289835     2.303444     2.293562     2.277809     2.274046
# 纯白莲蓉_6       2.727484     2.758092     2.768684     2.763091     2.753499
# 纯白豆蓉_1_0     5.110787     5.189073     5.257421     5.326648     5.409126
# 纯白豆蓉_2_0     5.477637     5.566579     5.676272     5.801456     5.930820
# 纯白豆蓉_3_0     5.254405     5.332560     5.427774     5.541492     5.669588
# 纯白豆蓉_4_0     6.425482     6.519026     6.611717     6.711975     6.825687
# 纯白豆蓉_5_0     6.378620     6.461216     6.542834     6.635716     6.749890
# 纯白豆蓉_6_0     5.858489     6.013079     6.183946     6.357814     6.522538
# 纯白豆蓉_7_0     5.730359     5.827879     5.922842     6.017995     6.121760
# 纯白豆蓉_8_0     7.312016     7.426744     7.547203     7.664685     7.773741
# 纯红豆沙_1_0     2.723711     2.739465     2.770403     2.827354     2.909915
# 纯红豆沙_2_0     2.050633     2.102562     2.154224     2.198695     2.232910
# 纯红豆沙_3_0     2.682259     2.743546     2.770658     2.763489     2.734949
# 纯红豆沙_4_0     2.575992     2.647624     2.693681     2.711586     2.713836
# 纯红豆沙_5_0     2.657032     2.682908     2.715127     2.754440     2.799727
# 纯红豆沙_6_0     2.618117     2.665320     2.702380     2.728801     2.745042
# 纯红豆沙_7_0     3.078088     3.106894     3.134635     3.161442     3.190196
# 纯红豆沙_8_0     3.117124     3.178000     3.231436     3.273036     3.302327
# 纯豌豆蓉_1_0     9.480497     9.631838     9.789496     9.957345    10.138941
# 纯豌豆蓉_2_0     9.009660     9.116569     9.219189     9.341937     9.503037
# 纯豌豆蓉_3_0     8.880121     9.011238     9.154616     9.321177     9.514933
# 纯豌豆蓉_4_0     7.902888     8.041554     8.182578     8.337391     8.512701
# 纯豌豆蓉_5_0     6.526964     6.654700     6.779762     6.907239     7.045324
# 纯豌豆蓉_6_0     9.686499     9.828897     9.981440    10.143284    10.313874
# 纯豌豆蓉_7_0     8.101461     8.264891     8.454105     8.645774     8.818830
# 纯豌豆蓉_8_0     8.998116     9.110738     9.234750     9.379023     9.549491
#
#           1299.955904
# 纯白莲蓉_1       2.605632
# 纯白莲蓉_2       2.676952
# 纯白莲蓉_3       2.299127
# 纯白莲蓉_4       2.293174
# 纯白莲蓉_6       2.755732
# 纯白豆蓉_1_0     5.512955
# 纯白豆蓉_2_0     6.052790
# 纯白豆蓉_3_0     5.804594
# 纯白豆蓉_4_0     6.953902
# 纯白豆蓉_5_0     6.889491
# 纯白豆蓉_6_0     6.671701
# 纯白豆蓉_7_0     6.245226
# 纯白豆蓉_8_0     7.877129
# 纯红豆沙_1_0     3.005440
# 纯红豆沙_2_0     2.259433
# 纯红豆沙_3_0     2.707448
# 纯红豆沙_4_0     2.722018
# 纯红豆沙_5_0     2.848352
# 纯红豆沙_6_0     2.754039
# 纯红豆沙_7_0     3.225834
# 纯红豆沙_8_0     3.322815
# 纯豌豆蓉_1_0    10.335957
# 纯豌豆蓉_2_0     9.707292
# 纯豌豆蓉_3_0     9.731931
# 纯豌豆蓉_4_0     8.708322
# 纯豌豆蓉_5_0     7.201355
# 纯豌豆蓉_6_0    10.493778
# 纯豌豆蓉_7_0     8.965752
# 纯豌豆蓉_8_0     9.747880
#
# [29 rows x 257 columns]

# %%
df.to_csv('纯蓉.csv')

# %% [markdown]
# ### 水质检测仪数据提取

# %%
import glob
import pandas as pd 
import numpy as np
file_list = glob.glob(rf'I:\experiment_data\宜茶\250604\*\specFile\continue_test_sample_*.csv')

# %%
spectrum = []
for file in file_list:
  df = pd.read_csv(file)
  spe = df.iloc[:,1].values
  spectrum.append(spe)

wave = df.iloc[:,0].values
spectrum = np.array(spectrum)

# %% [markdown]
# ### 海谱香精检测仪数据提取

# %%
import xml.etree.ElementTree as ET

def extract_wavelength(node):
    node_data = node[0]
    sample_nodes = node_data.findall('Sample')
    test_node = sample_nodes[0]
    polyline = test_node.find('polyline')
    
    value = polyline.get('points')
    value = str(value)
    str_list = value.split()
    k = len(str_list)
    
    wavelength = [None] * k
    for i in range(k):
        temp = str_list[i].split(",")
        wavelength[i] = temp[0]
    
    return wavelength

def extract_wavelength_for_all(node):
    test_node = node[0]
    polyline = test_node.find('polyline')
    
    value = polyline.get('points')
    value = str(value)
    str_list = value.split()
    k = len(str_list)
    
    wavelength = [None] * k
    for i in range(k):
        temp = str_list[i].split(",")
        wavelength[i] = temp[0]
    
    return wavelength

def read_dat_xml_fun(path):
    dom = ET.parse(path)

    ir_node = dom.findall('.//SWIRChart')
    vis_node = dom.findall('.//VISChart')
    uv_node = dom.findall('.//UVChart')

    ir_avg_node = dom.findall('.//SWIRAvgChart')
    vis_avg_node = dom.findall('.//VISAvgChart')
    uv_avg_node = dom.findall('.//UVAvgChart')
    all_avg_node = dom.findall('.//ALLAvgChart')

    ir_scatter_node = dom.findall('.//SWIRAvgScatter')
    vis_scatter_node = dom.findall('.//VISAvgScatter')
    uv_scatter_node = dom.findall('.//UVAvgScatter')
    all_scatter_node = dom.findall('.//ALLAvgScatter')

    table_node = dom.findall('.//Table')

    # 提取波长信息
    ir_wavelength = extract_wavelength(ir_node)
    uv_vis_wavelength = extract_wavelength(vis_node)
    all_wavelength = extract_wavelength_for_all(all_avg_node)

    # 提取原始数据
    ir_node_cell = extract_points(ir_node)
    vis_node_cell = extract_points(vis_node)
    uv_node_cell = extract_points(uv_node)

    # 提取透射平均后数据
    ir_avg_cell = extract_avg_points(ir_avg_node)
    vis_avg_cell = extract_avg_points(vis_avg_node)
    uv_avg_cell = extract_avg_points(uv_avg_node)
    all_avg_cell = extract_avg_points(all_avg_node)

    # 提取散点坐标数据
    ir_scatter_cell = extract_scatter_points(ir_scatter_node)
    vis_scatter_cell = extract_scatter_points(vis_scatter_node)
    uv_scatter_cell = extract_scatter_points(uv_scatter_node)
    all_scatter_cell = extract_scatter_points(all_scatter_node)

    # 提取一致性结果表格数据
    node_data = table_node[0]
    row_nodes = node_data.findall('Row')
    n = len(row_nodes)

    table_data = [[None] * 4 for _ in range(n)]
    order = [None] * n  # Table的sampleID顺序就是order
    for i, test_data in enumerate(row_nodes):
        cell_nodes = test_data.findall('Cell')
        
        k = len(cell_nodes)
        for j in range(1, k - 1):
            test_cell = cell_nodes[j]
            value = test_cell.text
            table_data[i][j - 1] = float(value)
        
        value = test_data.get('sampleID')
        order[i] = float(value)

    # 提取背景和source
    ir_bg_node = dom.findall('.//SWIRAvgBg')
    vis_bg_node = dom.findall('.//VISAvgBg')
    uv_bg_node = dom.findall('.//UVAvgBg')

    ir_src_node = dom.findall('.//SWIRAvgSrc')
    vis_src_node = dom.findall('.//VISAvgSrc')
    uv_src_node = dom.findall('.//UVAvgSrc')

    ir_bg_cell = extract_avg_points(ir_bg_node)
    vis_bg_cell = extract_avg_points(vis_bg_node)
    uv_bg_cell = extract_avg_points(uv_bg_node)

    ir_src_cell = extract_avg_points(ir_src_node)
    vis_src_cell = extract_avg_points(vis_src_node)
    uv_src_cell = extract_avg_points(uv_src_node)

    # 重排顺序
    real_order = [i[0] for i in sorted(enumerate(order), key=lambda x: x[1])]

    # 好几个数据都要重排，除了table和scatter
    ir_node_cell = [ir_node_cell[i] for i in real_order]
    vis_node_cell = [vis_node_cell[i] for i in real_order]
    uv_node_cell = [uv_node_cell[i] for i in real_order]

    ir_avg_cell = [ir_avg_cell[i] for i in real_order]
    vis_avg_cell = [vis_avg_cell[i] for i in real_order]
    uv_avg_cell = [uv_avg_cell[i] for i in real_order]
    all_avg_cell = [all_avg_cell[i] for i in real_order]

    # 提取名称
    name_cell = [cell_nodes[0].text for cell_nodes in row_nodes]
    name_cell = [name_cell[i] for i in real_order]

    # 统一到一个结构里面保存
    result = {
        'ir_wavelength': ir_wavelength,
        'uv_vis_wavelength': uv_vis_wavelength,
        'all_wavelength': all_wavelength,

        'ir_node_cell': ir_node_cell,
        'vis_node_cell': vis_node_cell,
        'uv_node_cell': uv_node_cell,

        'ir_avg_cell': ir_avg_cell,
        'vis_avg_cell': vis_avg_cell,
        'uv_avg_cell': uv_avg_cell,
        'all_avg_cell': all_avg_cell,

        'ir_scatter_cell': ir_scatter_cell,
        'vis_scatter_cell': vis_scatter_cell,
        'uv_scatter_cell': uv_scatter_cell,
        'all_scatter_cell': all_scatter_cell,

        'ir_bg_cell': ir_bg_cell,
        'vis_bg_cell': vis_bg_cell,
        'uv_bg_cell': uv_bg_cell,

        'ir_src_cell': ir_src_cell,
        'vis_src_cell': vis_src_cell,
        'uv_src_cell': uv_src_cell,

        'table_data': table_data,
        'name_cell': name_cell
    }

    return result

def extract_avg_points(node):
    node_data = node[0]
    sample_nodes = node_data.findall('polyline')
    n = len(sample_nodes)

    data = sample_nodes[0]
    value = data.get('points')
    value = str(value)
    str_list = value.split()
    k = len(str_list)

    sample_cell = [[None] * k for _ in range(n)]

    for i, data in enumerate(sample_nodes):
        value = data.get('points')
        value = str(value)
        str_list = value.split()

        for j, temp in enumerate(str_list):
            sample_cell[i][j] = float(temp.split(',')[1])
    
    return sample_cell


def extract_points(node):
    node_data = node[0]
    sample_nodes = node_data.findall('Sample')
    n = len(sample_nodes)
    sample_cell = [None] * n

    for i, data in enumerate(sample_nodes):
        polyline = data.findall('polyline')
        m = len(polyline)
        test = polyline[0]
        value = test.get('points')
        value = str(value)
        str_list = value.split()
        k = len(str_list)

        sample_data = [[None] * k for _ in range(m)]

        for j, test in enumerate(polyline):
            value = test.get('points')
            value = str(value)
            str_list = value.split()

            for w, temp in enumerate(str_list):
                sample_data[j][w] = float(temp.split(',')[1])

        sample_cell[i] = sample_data

    return sample_cell

def extract_scatter_points(node):
    node_data = node[0]
    sample_nodes = node_data.findall('polyline')
    n = len(sample_nodes)

    sample_cell = [None] * n

    for i, data in enumerate(sample_nodes):
        value = data.get('points')
        value = str(value)
        str_list = value.split()
        k = len(str_list)

        scatter_data = [[None] * 2 for _ in range(k)]

        for j, temp in enumerate(str_list):
            temp_split = temp.split(',')
            scatter_data[j] = [float(temp_split[0]), float(temp_split[1])]

        sample_cell[i] = scatter_data

    return sample_cell

# %%
import glob
import numpy as np
import pandas as pd
file_list = glob.glob(rf'I:\experiment_data\洗脱液\废液\*.dat')

transmittance = []
labels = []
for file in file_list : 
    result = read_dat_xml_fun(file)
    transmittance.append(np.array(result['all_avg_cell']))
    labels.append([file.split('\\')[-1][:-4]]*np.array(result['all_avg_cell']).shape[0])
                                     
labels = np.concat(labels)
labels = labels.reshape(-1)
transmittance = np.concat(transmittance)
wavelengths =[float(x) for x in result['all_wavelength']]
transmittance_pd = pd.DataFrame(transmittance, index=labels, columns=wavelengths)
# transmittance_pd = transmittance_pd.groupby(transmittance_pd.index).first()
transmittance_pd
# Out:
#           202.129   202.585   203.041   203.496   203.952   204.408   \
# 山海棠药材提取液   73.3948   69.0951   65.2124   61.7290   58.6273   55.8895
# 山海棠药材提取液   77.2861   72.4258   68.0331   64.0879   60.5705   57.4611
# 山海棠药材提取液   80.5034   75.1109   70.2349   65.8536   61.9452   58.4879
# 山海棠药材提取液   65.7584   62.5847   59.7277   57.1737   54.9090   52.9200
# 废液1        91.2053   92.1483   93.0086   93.7898   94.4950   95.1275
# 废液1        72.6104   68.1706   64.1667   60.5803   57.3929   54.5860
# 废液1        69.7958   65.9734   62.5240   59.4320   56.6815   54.2569
# 废液1        59.8658   57.5659   55.5003   53.6590   52.0320   50.6092
# 废液2        48.2966   46.8665   45.6033   44.4997   43.5480   42.7410
# 废液2        43.5172   43.0439   42.6455   42.3184   42.0590   41.8637
# 废液2        53.9717   51.9183   50.0833   48.4572   47.0304   45.7935
# 废液3        56.8584   54.4958   52.3852   50.5157   48.8760   47.4551
# 废液3        52.3264   50.7145   49.2877   48.0378   46.9564   46.0350
# 废液3        62.9266   59.8042   56.9909   54.4736   52.2392   50.2746
# 废液4        68.8406   66.4281   64.2538   62.3079   60.5803   59.0610
# 废液4        81.3020   76.9536   73.0159   69.4720   66.3048   63.4972
#
#           204.864   205.320   205.776   206.232   ...  1626.540  1634.750  \
# 山海棠药材提取液   53.4980   51.4352   49.6832   48.2246  ...   37.3576   37.0659
# 山海棠药材提取液   54.7400   52.3873   50.3832   48.7079  ...   37.4517   37.1659
# 山海棠药材提取液   55.4600   52.8397   50.6052   48.7348  ...   37.5812   37.2927
# 山海棠药材提取液   51.1929   49.7139   48.4695   47.4457  ...   36.4976   36.2098
# 废液1        95.6907   96.1879   96.6224   96.9973  ...   99.0118   99.0119
# 废液1        52.1412   50.0399   48.2637   46.7942  ...   32.1254   33.2570
# 废液1        52.1424   50.3225   48.7813   47.5031  ...   31.6964   32.8252
# 废液1        49.3804   48.3357   47.4651   46.7583  ...   32.4892   33.5981
# 废液2        42.0710   41.5307   41.1125   40.8091  ...   29.8760   30.9376
# 废液2        41.7290   41.6512   41.6269   41.6523  ...   29.0495   30.1176
# 废液2        44.7368   43.8508   43.1258   42.5525  ...   30.0908   31.1154
# 废液3        46.2420   45.2255   44.3945   43.7380  ...   30.4395   31.4579
# 废液3        45.2655   44.6394   44.1484   43.7841  ...   30.0894   31.1791
# 废液3        48.5667   47.1024   45.8686   44.8522  ...   30.7024   31.7693
# 废液4        57.7401   56.6076   55.6534   54.8677  ...   37.8203   37.5307
# 废液4        61.0323   58.8929   57.0621   55.5228  ...   37.9540   37.6648
#
#           1642.960  1651.170  1659.390  1667.610  1675.830  1684.050  \
# 山海棠药材提取液   36.8257   36.6397   36.5201   36.5155   36.6947   37.0751
# 山海棠药材提取液   36.9324   36.7538   36.6462   36.6553   36.8425   37.2275
# 山海棠药材提取液   37.0581   36.8786   36.7655   36.7696   36.9553   37.3410
# 山海棠药材提取液   35.9744   35.7956   35.6858   35.6939   35.8818   36.2711
# 废液1        99.0086   99.0073   99.0000   98.9877   98.9714   98.9610
# 废液1        34.3537   35.2320   35.7552   36.4087   36.9176   37.3420
# 废液1        33.9188   34.8001   35.4018   35.9681   36.4530   36.8850
# 废液1        34.7541   35.6647   36.1688   36.7300   37.2495   37.7070
# 废液2        31.9988   32.9167   33.5312   33.9611   34.4677   34.8258
# 废液2        31.1635   31.9817   32.5683   33.0531   33.5748   33.9731
# 废液2        32.0796   32.9773   33.6393   34.1125   34.5650   34.9059
# 废液3        32.5429   33.3662   33.9455   34.5125   34.9660   35.3357
# 废液3        32.2784   33.1414   33.6386   34.1949   34.7220   35.1822
# 废液3        32.8335   33.7023   34.2575   34.8144   35.2956   35.6597
# 废液4        37.2961   37.1138   37.0008   37.0034   37.1859   37.5647
# 废液4        37.4310   37.2505   37.1405   37.1467   37.3321   37.7129
#
#           1692.270  1700.500
# 山海棠药材提取液   37.5934   38.1801
# 山海棠药材提取液   37.7469   38.3332
# 山海棠药材提取液   37.8621   38.4501
# 山海棠药材提取液   36.7968   37.3902
# 废液1        98.9568   98.9549
# 废液1        38.0116   39.1591
# 废液1        37.5806   38.6659
# 废液1        38.3425   39.5106
# 废液2        35.5164   36.6856
# 废液2        34.6112   35.5134
# 废液2        35.6147   36.6907
# 废液3        36.0458   37.1004
# 废液3        35.8302   36.8146
# 废液3        36.3044   37.4494
# 废液4        38.0762   38.6528
# 废液4        38.2255   38.8024
#
# [16 rows x 2102 columns]

# %%
# transmittance_pd.to_csv('废液与提取液.csv')
